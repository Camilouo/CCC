# %%
nombre=(str(input("Ingrese su nombre: ")))
print("Bienvenido \N{WAVING HAND SIGN} " + nombre)
print("Este escrito se divide en dos, un año despues del dia de hoy y 5 años despues, que lo disfrutes! :D")
# Out:
# Ingrese su nombre: lol
# Bienvenido 👋 lol
# Este escrito se divide en dos, un año despues del dia de hoy y 5 años despues, que lo disfrutes! :D

# %%
print("".rjust(127,'-'))
print("Primera Actividad / Programación".center(125))
print("".rjust(127,'-'))
# Out:
# -------------------------------------------------------------------------------------------------------------------------------
#                                                Primera Actividad / Programación
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## <font color='BLACK'>**Un año despues**</font>
#
#
# <p style='text-align: justify;'>
#
# <font color='FF9998'>Hoy 15 de febrero del 2023 tengo clase de 9am, voy tarde y sin desayunar... Pero feliz con lo que he logrado durante este tiempó. 1 año despues de haber sido admitido en el ✨Exterminio✨ conoci muy buenas personas que nutrieron mi experiencia en la carrera que aún despues de un año nadie conoce en la Universidad... </font>
#
# <font color='FF9998'>Academicamente, me ha ido bien :) Pues mi ''fuerte'' es programación y domino lenguajes como Python y R, apesar de que en Calculo no me vaya muy bien, lo intento y me esfuerzo por mantener un promedio decente, y el necesario para que no me quiten la beca hahahaha, este año he decidido construir una aplicacion capaz de captar datos y hacer predicciones en la gente, es algo basico pero es el comienzo de un proyecto a largo plazo, he pedido ayuda de mis dos mejores amigos de carrera, todos tenemos algo en común, crear una empresa. </font>

# %% [markdown]
# ## <font color='BLACK'>**Cinco años despues**</font>
#
# <p style='text-align: justify;'>
# <font color='7e4370'>Ya paso un tiempo despues que me gradue, inicio otra etapa en mi vida. Desde que estuve en la universidad pude empezar a construir un emprendimiento empresarial a largo plazo en el cual estan involucrados unos de mis primeros amigos en el Externado,  la universidad me ha brindado todas las herramientas para lanzar este proyecto. Un año despues este proyecto se pudo lanzar al mercado y ha tenido muy buenos resultados, espero seguir nutriendo este proyecto y consolidar la empresa como una de las mejores en cuanto a BigData en latam.</font>
# <p style='text-align: justify;'>
# <font color='7e4370'>Logre obtener un buen empleo y aun recuerdo que en mi primer semestre de universidad todo mundo decia que no nos debiamos preocupar por conseguir empleo, que siempre habrian ofertas <b>(Ojalá)</b> y así fue, ademas del proyecto empresarial que cree con la ayuda de algunos compañeros de carrera, tambien trabajo con el gobierno recogiendo informacion acerca de las comunidades alejadas de la capital, buscando la mejor manera de intervenir en estas comunidades. Academicamente me gustaria seguir profundizando e irme especializando totalmente en ciberseguridad y privacidad, ya como cientifico de datos tengo un gran reconocimiento y responsabilidad, pero ahora las metas son mas ambiciosas, en pocos meses ire a US a tantear mejor el terreno y lograr aun mas experiencia en el sector, sera un periodo breve y con objetivos claros;
#
# * Aprender
#     * Expandir mi proyecto empresarial
#         * Aportar en la industria Colombiana
#     </font>
# <font color='blue'>Actualmente no deseo casarme y no creo que quiera hacerlo, pero no se descarta la posibilidad.
# En esto se resume mi trayecto 5 años despues de ese agotador e interminable primer semestre, agradecido con la vida por esta oportunidad y con el Externado por abrir esta carrera, muy visionarios, tqm externado. </font>

# %% [markdown]
# <p style='text-align: right;'>
# <i>
# "Lo que con mucho trabajo se adquiere, más se ama". Aristóteles.
# </i>
# </p>

# %%
print("".rjust(127,'-'))
print("Fin".center(125))

print("Cristian Camilo Avendaño Nieto \nCiencia de Datos")

print("".rjust(127,'-'))
# Out:
# -------------------------------------------------------------------------------------------------------------------------------
#                                                              Fin
# Cristian Camilo Avendaño Nieto
# Ciencia de Datos
# -------------------------------------------------------------------------------------------------------------------------------

# %%
Edad =(int,str(input("¿A qué hora era la clase de Camilo? Ingresar solo número entero e indicar am o pm ")))

print("!!Exacto a esa hora tenia clase¡¡")
      
#Queria hacer un codigo el cual hiciera que al ingresar cualquier otro dato distinto de 9, arrojara error pero
#creo no se puede hacer sin tener un condicional :(
# Out:
# ¿A qué hora era la clase de Camilo? Ingresar solo número entero e indicar am o pm 9am
# !!Exacto a esa hora tenia clase¡¡

# %%
Universidad =(str(input("¿Cómo se llama la universidad donde estudia Camilo?  ")))

print("Camilo estudia en el " + Universidad)
# Out:
# ¿Cómo se llama la universidad donde estudia Camilo?  externado
# Camilo estudia en el externado

# %% [markdown]
# ## Información adicional
# <p style='text-align: right;'>Aquí informacion mas puntual de mi :)

# %%
my_age=24
est=1.79

print("Tengo", my_age,"años,"+" mido",est)
print("Vivo en Bogotá DC" + " y en unos meses ire al extranjero")
print("Tengo una mascota, un gato de 4 años de edad")
# Out:
# Tengo 24 años, mido 1.79
# Vivo en Bogotá DC y en unos meses ire al extranjero
# Tengo una mascota, un gato de 4 años de edad

# %%
print("Hablame de ti, qué edad tienes?")
input()
print("A qué te dedicas? ")
input()
print("Donde vives")
input()
print("!wooow¡")
print("Un gusto conocerte :)")
# Out:
# Hablame de ti, qué edad tienes?
# 19
# A qué te dedicas?
# 20
# Donde vives
# 13
# !wooow¡
# Un gusto conocerte :)
